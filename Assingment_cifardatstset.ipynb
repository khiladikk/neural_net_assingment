# %%
# Importing the dependencies
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random as random

# %%
# downloading the dataset using keras api
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# ...
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
# Visualizing the dataset
fig = plt.figure(figsize=(20,5))
for i in range(30):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# Flatting all the images
x_train_flat = []
for i in range(0,len(x_train)):
  x_train_flat.append(np.ndarray.flatten(x_train[i]))
  
print(np.array(x_train_flat).shape)
# Out:
# (50000, 3072)

# %%
# making our target variables continuous 
# for that we will normalise values for each values
# it will be between 10-100

for i in range(0,len(y_train)):
  
  if(y_train[i][0]==0):
    y_train[i][0] = random.randint(0,10)
    
  if(y_train[i][0]==1):
    y_train[i][0] = random.randint(10,20)
    
  if(y_train[i][0]==2):
    y_train[i][0] = random.randint(20,30)
    
  if(y_train[i][0]==3):
    y_train[i][0] = random.randint(30,40)
    
  if(y_train[i][0]==4):
    y_train[i][0] = random.randint(40,50)
    
  if(y_train[i][0]==5):
    y_train[i][0] = random.randint(50,60)
    
  if(y_train[i][0]==6):
    y_train[i][0] = random.randint(60,70)
    
  if(y_train[i][0]==7):
    y_train[i][0] = random.randint(70,80)
    
  if(y_train[i][0]==8):
    y_train[i][0] = random.randint(80,90)
    
  if(y_train[i][0]==9):
    y_train[i][0] = random.randint(90,100)

# %%
x_train_flat = np.array(x_train_flat)
len(x_train_flat.T)
# Out:
# 3072

# %%
y_train = np.ndarray.flatten(y_train)
print(y_train[1:10])
# Out:
# [92 93 49 18 12 25 78 87 39]

# %%
Num_Features = 784
x_ph = tf.placeholder(tf.float64,[None,Num_Features])
y_ph = tf.placeholder(tf.float64,[None,10])
M1 = np.random.randn(Num_Features,Num_Features)
M1 = tf.Variable(M1)

print("Data Shape: ",X_place.shape)
print("M1 Shape:",M1.shape)
# Out:
# Data Shape:  (?, 784)
# M1 Shape: (784, 784)

# %%
L1Out = tf.nn.sigmoid(tf.matmul(X_place,M1))
M2 = np.random.randn(Num_Features,Num_Features)
M2 = tf.Variable(M2)
L2Out = tf.nn.sigmoid(tf.matmul(L1Out,M2))
M3 = np.random.randn(Num_Features,Num_Features)
M3 = tf.Variable(M3)
L3Out = tf.nn.sigmoid(tf.matmul(L2Out,M3))
M4 = np.random.randn(Num_Features,Num_Features)
M4 = tf.Variable(M4)
L4Out = tf.nn.sigmoid(tf.matmul(L3Out,M4))

print(L4Out)

Final_out = tf.nn.sigmoid(tf.matmul(L3Out,M4))

cost = tf.reduce_mean(tf.square(Final_out - y_ph))
# Out:
# Tensor("Sigmoid_13:0", shape=(?, 784), dtype=float64)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1863   try:
# -> 1864     c_op = c_api.TF_FinishOperation(op_desc)
#    1865   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Dimensions must be equal, but are 784 and 10 for 'sub_3' (op: 'Sub') with input shapes: [?,784], [?,10].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-96f2e0f5d594> in <module>()
#      14 Final_out = tf.nn.sigmoid(tf.matmul(L3Out,M4))
#      15
# ---> 16 cost = tf.reduce_mean(tf.square(Final_out - y_ph))
#
# ...

# %%
cost = tf.reduce_mean(tf.square(Final_out - Y_place))
Optimizer = tf.train.RMSPropOptimizer(learning_rate = 0.00001)
Minimize_The_Error = Optimizer.minimize(cost)
Init = tf.global_variables_initializer()
S = tf.Session()
S.run(Init)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1863   try:
# -> 1864     c_op = c_api.TF_FinishOperation(op_desc)
#    1865   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Dimensions must be equal, but are 784 and 10 for 'sub_4' (op: 'Sub') with input shapes: [?,784], [?,10].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d3d2c073b8b9> in <module>()
# ----> 1 cost = tf.reduce_mean(tf.square(Final_out - Y_place))
#       2 Optimizer = tf.train.RMSPropOptimizer(learning_rate = 0.00001)
#       3 Minimize_The_Error = Optimizer.minimize(cost)
#       4 Init = tf.global_variables_initializer()
# ...

# %%
from IPython.display import clear_output
iterations = 20
error = []
BATCH_SIZE = 1
for i in range(iterations):
  random_indices = np.random.randint(0,len(x_train),size = BATCH_SIZE)
  FD = {X_place: np.array(x_train,Y_place)}
  S.run(Minimize_The_Error,feed_dict = FD)
  error.append(S.run(cost,feed_dict = FD))
  clear_output(True)
  print("Current Iteration:", i, "Current Cost: ",S.run(cost,feed_dict = FD))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-291cc635175f> in <module>()
#       5 for i in range(iterations):
#       6   random_indices = np.random.randint(0,len(x_train),size = BATCH_SIZE)
# ----> 7   FD = {X_place: np.array(x_train,Y_place)}
#       8   S.run(Minimize_The_Error,feed_dict = FD)
#       9   error.append(S.run(cost,feed_dict = FD))
#
# TypeError: data type not understood
